# %%
import os
import cv2
import numpy as np
import re
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import shutil

# %%
def extract_page_info(filename):
    """Extract page number from a filename like 'measure_001_page1.png'"""
    page_match = re.search(r'page(\d+)', filename)
    if page_match:
        return int(page_match.group(1))
    return None

# %%
def get_sheet_music_files(directory):
    """Find all sheet music PNG files in a directory"""
    sheet_files = []
    for filename in os.listdir(directory):
        if filename.lower().endswith('.png') and not filename.startswith('measure_'):
            sheet_files.append(filename)
    return sheet_files

# %%
def match_sheet_to_page(sheet_filename, page_number):
    """Check if a sheet music filename corresponds to a specific page number."""
    base_name = os.path.splitext(sheet_filename)[0]
    page_indicators = [f"_{page_number}", f"-{page_number}"]
    
    for indicator in page_indicators:
        if base_name.endswith(indicator):
            return True
    
    if page_number == 1 and not any(base_name.endswith(f"_{i}") or base_name.endswith(f"-{i}") 
                                   for i in range(1, 10)):
        return True
    
    return False

# %%
def visualize_detailed_ordering(full_sheet_path, matches, output_path=None):
    """Create a visualization showing the exact ordering of measures."""
    full_sheet_img = cv2.imread(full_sheet_path)
    if full_sheet_img is None:
        print(f"Could not read full sheet music image: {full_sheet_path}")
        return
    
    # Extract original measure numbers for reference
    orig_numbers = {}
    for match in matches:
        filename = match['filename']
        num_match = re.search(r'measure_(\d+)_', filename)
        if num_match:
            orig_numbers[filename] = int(num_match.group(1))
    
    # Draw measures with ordering information
    for i, match in enumerate(matches, 1):
        top_left = match['top_left']
        w, h = match['width'], match['height']
        bottom_right = (top_left[0] + w, top_left[1] + h)
        
        # Draw rectangle with row-specific colors
        row_colors = [
            (0, 255, 0),    # Green
            (0, 200, 255),  # Yellow
            (0, 128, 255),  # Orange
            (0, 0, 255),    # Red
            (255, 0, 255),  # Purple
            (255, 0, 0)     # Blue
        ]
        color = row_colors[match['row'] % len(row_colors)]
        cv2.rectangle(full_sheet_img, top_left, bottom_right, color, 2)
        
        # Draw ordering information
        orig_num = orig_numbers.get(match['filename'], '?')
        
        # Draw sequential number (new ordering)
        cv2.putText(full_sheet_img, f"{i}", 
                   (top_left[0] + 5, top_left[1] + 20),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        
        # Draw original number and scale if not 1.0
        scale_text = f" s:{match['scale']:.1f}" if 'scale' in match and match['scale'] != 1.0 else ""
        cv2.putText(full_sheet_img, f"({orig_num}{scale_text})", 
                   (top_left[0] + 5, top_left[1] + 45),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
        
        # Draw row number
        cv2.putText(full_sheet_img, f"r{match['row']}", 
                   (top_left[0] + w - 30, top_left[1] + 20),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    
    # Convert from BGR to RGB for matplotlib
    rgb_img = cv2.cvtColor(full_sheet_img, cv2.COLOR_BGR2RGB)
    
    # Display or save the image
    plt.figure(figsize=(15, 15))
    plt.imshow(rgb_img)
    plt.title(f"Measure Ordering (New Number with Original in Parentheses)")
    plt.axis('off')
    
    if output_path:
        plt.savefig(output_path)
        print(f"Visualization saved to {output_path}")
    else:
        plt.show()
    
    plt.close()

# %%
def multi_scale_template_match(full_sheet_img, measure_img, max_scale=2.5, min_scale=0.1, scale_steps=75):
    """
    Perform template matching with multiple scales to handle different sized measures.
    
    Args:
        full_sheet_img: Full sheet music image
        measure_img: Measure image to match
        max_scale: Maximum scaling factor
        min_scale: Minimum scaling factor
        scale_steps: Number of scaling steps to try
        
    Returns:
        best_match: Dictionary with match information
    """
    best_match = {
        'confidence': 0,
        'top_left': None,
        'scale': 1.0,
        'width': measure_img.shape[1],
        'height': measure_img.shape[0]
    }
    
    # Try exact match first (scale = 1.0)
    result = cv2.matchTemplate(full_sheet_img, measure_img, cv2.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
    
    # If we get a perfect or near-perfect match, return immediately
    if max_val > 0.7:
        best_match['confidence'] = max_val
        best_match['top_left'] = max_loc
        return best_match
    
    # Update best match
    if max_val > best_match['confidence']:
        best_match['confidence'] = max_val
        best_match['top_left'] = max_loc
    
    # Try different scales
    scales = np.linspace(min_scale, max_scale, scale_steps)
    for scale in scales:
        # Skip scale 1.0 as we already tried it
        if scale == 1.0:
            continue
            
        # Resize the measure image
        width = int(measure_img.shape[1] * scale)
        height = int(measure_img.shape[0] * scale)
        if width <= 0 or height <= 0:
            continue
            
        resized_measure = cv2.resize(measure_img, (width, height), interpolation=cv2.INTER_AREA)
        
        # Perform template matching
        try:
            result = cv2.matchTemplate(full_sheet_img, resized_measure, cv2.TM_CCOEFF_NORMED)
            min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
            
            # Update best match if this is better
            if max_val > best_match['confidence']:
                best_match['confidence'] = max_val
                best_match['top_left'] = max_loc
                best_match['scale'] = scale
                best_match['width'] = width
                best_match['height'] = height
        except cv2.error:
            # Skip if there's an error (e.g., template larger than image)
            continue
    
    return best_match

# %%
def process_song_folder(song_folder, create_visualization=True, row_threshold=100):
    """
    Process a single song folder containing sheet music and measures.
    
    Args:
        song_folder: Path to the song folder
        create_visualization: Whether to create visualization images
        row_threshold: Distance threshold for grouping measures into rows (larger = more measures in same row)
    """
    print(f"\nProcessing song folder: {os.path.basename(song_folder)}")
    
    # Find the measures subfolder
    measures_dir = os.path.join(song_folder, "ordered_measures")
    if not os.path.exists(measures_dir):
        print(f"No measures folder found in {song_folder}, skipping.")
        return False
    
    # Create output directory for ordered measures
    output_dir = os.path.join(song_folder, "final_measures")
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created output directory: {output_dir}")
    
    # Get all measure image files
    measure_files = [f for f in os.listdir(measures_dir) 
                   if f.lower().endswith('.png') and 'measure_' in f]
    
    if not measure_files:
        print(f"No measure files found in {measures_dir}, skipping.")
        return False
    
    # Group measure files by page
    measures_by_page = {}
    for filename in measure_files:
        page_number = extract_page_info(filename)
        if page_number is not None:
            if page_number not in measures_by_page:
                measures_by_page[page_number] = []
            measures_by_page[page_number].append(filename)
    
    # Get all sheet music files
    sheet_files = get_sheet_music_files(song_folder)
    
    if not sheet_files:
        print(f"No sheet music PNG files found in {song_folder}, skipping.")
        return False
    
    all_matches = []
    
    # Create output directory for visualizations
    if create_visualization:
        viz_dir = os.path.join(song_folder, "new_visualizations")
        if not os.path.exists(viz_dir):
            os.makedirs(viz_dir)
    
    # Process each page
    for page_number, page_measures in measures_by_page.items():
        # Find corresponding sheet music file for this page
        sheet_file = None
        for f in sheet_files:
            if match_sheet_to_page(f, page_number):
                sheet_file = f
                break
        
        if not sheet_file:
            print(f"Warning: No matching sheet music found for page {page_number}.")
            continue
        
        full_sheet_path = os.path.join(song_folder, sheet_file)
        print(f"Processing page {page_number} with sheet music: {sheet_file}")
        
        # Load the full sheet music image
        full_sheet_img = cv2.imread(full_sheet_path, cv2.IMREAD_GRAYSCALE)
        if full_sheet_img is None:
            print(f"Could not read sheet music image: {full_sheet_path}")
            continue
        
        matches = []
        
        # Process each measure image for this page
        for filename in page_measures:
            filepath = os.path.join(measures_dir, filename)
            try:
                measure_img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
                
                if measure_img is None:
                    print(f"Could not read measure image: {filepath}")
                    continue
                
                # Use multi-scale template matching to handle different sized measures
                match_result = multi_scale_template_match(
                    full_sheet_img, 
                    measure_img
                )
                
                if match_result['confidence'] < 0.5:
                    print(f"Warning: Low match confidence ({match_result['confidence']:.2f}) for {filename}")
                    continue
                
                top_left = match_result['top_left']
                h, w = match_result['height'], match_result['width']
                center_x = top_left[0] + w // 2
                center_y = top_left[1] + h // 2
                
                matches.append({
                    'filename': filename,
                    'top_left': top_left,
                    'center': (center_x, center_y),
                    'confidence': match_result['confidence'],
                    'width': w,
                    'height': h,
                    'scale': match_result['scale'],
                    'page': page_number
                })
                
                scale_info = f" (scale: {match_result['scale']:.2f})" if match_result['scale'] != 1.0 else ""
                print(f"Matched {filename} at position {top_left} with confidence {match_result['confidence']:.2f}{scale_info}")
                
            except Exception as e:
                print(f"Error processing {filename}: {e}")
        
        if not matches:
            continue
            
        # Get sheet height to calculate relative positions
        sheet_height = full_sheet_img.shape[0]
        
        # Perform row detection with DBSCAN
        y_coords = np.array([m['center'][1] for m in matches]).reshape(-1, 1)
        clustering = DBSCAN(eps=row_threshold, min_samples=1).fit(y_coords)
        
        # Calculate median y-coordinate for each cluster
        cluster_labels = set(clustering.labels_)
        cluster_medians = {}
        for label in cluster_labels:
            indices = [i for i, x in enumerate(clustering.labels_) if x == label]
            y_values = [matches[i]['center'][1] for i in indices]
            cluster_medians[label] = np.median(y_values)
        
        # Sort clusters by median y-coordinate (top to bottom)
        sorted_labels = sorted(cluster_labels, key=lambda l: cluster_medians[l])
        
        # Map cluster label to row number
        label_to_row = {label: row for row, label in enumerate(sorted_labels)}
        
        # Assign rows to measures
        for match in matches:
            idx = matches.index(match)
            cluster_label = clustering.labels_[idx]
            match['row'] = label_to_row[cluster_label]
            
            # Normalize vertical position as percentage of page height
            match['y_pct'] = match['center'][1] / sheet_height
        
        # Group measures by row
        rows = {}
        for match in matches:
            row = match['row']
            if row not in rows:
                rows[row] = []
            rows[row].append(match)
        
        # Sort rows by vertical position
        sorted_rows = sorted(rows.keys())
        
        # Sort each row by x-coordinate only
        for row in sorted_rows:
            rows[row].sort(key=lambda m: m['center'][0])
        
        # Flatten rows back into a single list in reading order
        ordered_matches = []
        for row in sorted_rows:
            ordered_matches.extend(rows[row])
        
        # Create visualization if requested
        if create_visualization:
            viz_path = os.path.join(viz_dir, f"ordering_page{page_number}.png")
            visualize_detailed_ordering(full_sheet_path, ordered_matches, viz_path)
        
        all_matches.extend(ordered_matches)
    
    # Sort all matches by page number
    all_matches.sort(key=lambda m: m['page'])
    
    # Copy measures to output directory with new names
    measure_count = 1
    copied_count = 0
    
    # Track which files have been copied to avoid duplicates
    copied_files = set()
    
    for match in all_matches:
        source_path = os.path.join(measures_dir, match['filename'])
        page_part = f"page{match['page']}"
        
        # Extract current measure number for debugging
        current_num_match = re.search(r'measure_(\d+)_', match['filename'])
        current_num = current_num_match.group(1) if current_num_match else "unknown"
        
        # Create new filename with updated measure number but keeping the page info
        new_filename = f"measure_{measure_count:03d}_{page_part}.png"
        dest_path = os.path.join(output_dir, new_filename)
        
        # Check if we already have this destination file to avoid overwrites
        if dest_path in copied_files:
            print(f"Warning: Destination {new_filename} already exists. Skipping duplicate.")
            continue
        
        try:
            # Copy instead of rename
            shutil.copy2(source_path, dest_path)
            copied_files.add(dest_path)
            print(f"Copied measure_{current_num}_{page_part}.png to {new_filename}")
            copied_count += 1
        except Exception as e:
            print(f"Error copying {match['filename']}: {e}")
        
        measure_count += 1
    
    print(f"Finished processing song folder: {os.path.basename(song_folder)}")
    print(f"Total measures: {len(all_matches)}, Copied: {copied_count}")
    print(f"Ordered measures saved to: {output_dir}")
    
    return True

# %%
def batch_process_songs(root_folder, create_visualization=True, row_threshold=100):
    """Process all song folders within the root folder."""
    print(f"Starting batch processing in: {root_folder}")
    print(f"Using row threshold: {row_threshold}px")
    
    # Get all subdirectories (song folders)
    song_folders = []
    for item in os.listdir(root_folder):
        item_path = os.path.join(root_folder, item)
        if os.path.isdir(item_path):
            song_folders.append(item_path)
    
    if not song_folders:
        print("No song folders found.")
        return
    
    print(f"Found {len(song_folders)} song folders.")
    
    # Process each song folder
    successful = 0
    for song_folder in song_folders:
        if process_song_folder(song_folder, create_visualization, row_threshold):
            successful += 1
    
    print(f"\nBatch processing complete. Successfully processed {successful} out of {len(song_folders)} song folders.")

# %%
root_dir = 'measures_pngs'

# Process all song folders
batch_process_songs(root_dir, row_threshold=80)
# Out:
# Starting batch processing in: measures_pngs
# Using row threshold: 80px
# Found 220 song folders.
#
# Processing song folder: How-Insensitive
# Created output directory: measures_pngs/How-Insensitive/final_measures
# Processing page 1 with sheet music: How-Insensitive_1.png
# Matched measure_017_page1.png at position (1913, 1527) with confidence 1.00
# Matched measure_003_page1.png at position (769, 583) with confidence 1.00
# Matched measure_022_page1.png at position (277, 2258) with confidence 1.00
# Matched measure_029_page1.png at position (1966, 2511) with confidence 1.00
# Matched measure_008_page1.png at position (1334, 899) with confidence 1.00
# Matched measure_024_page1.png at position (1392, 2239) with confidence 1.00
# Matched measure_030_page1.png at position (308, 2940) with confidence 1.00
# Matched measure_011_page1.png at position (797, 1279) with confidence 1.00
# Matched measure_005_page1.png at position (1873, 557) with confidence 1.00
# Matched measure_016_page1.png at position (1365, 1565) with confidence 1.00
# Matched measure_023_page1.png at position (848, 2234) with confidence 1.00
# Matched measure_028_page1.png at position (1420, 2552) with confidence 1.00
# Matched measure_009_page1.png at position (1879, 899) with confidence 1.00
# Matched measure_031_page1.png at position (880, 2910) with confidence 1.00
# Matched measure_025_page1.png at position (1948, 2199) with confidence 1.00
# Matched measure_004_page1.png at position (1319, 545) with confidence 1.00
# Matched measure_010_page1.png at position (222, 1276) with confidence 1.00
# Matched measure_018_page1.png at position (234, 1952) with confidence 1.00
# Matched measure_020_page1.png at position (1378, 1919) with confidence 1.00
# Matched measure_015_page1.png at position (809, 1558) with confidence 1.00
# Matched measure_001_page1.png at position (177, 608) with confidence 1.00
# Matched measure_013_page1.png at position (1898, 1210) with confidence 1.00
# Matched measure_007_page1.png at position (783, 939) with confidence 1.00
# Matched measure_026_page1.png at position (279, 2610) with confidence 1.00
# Matched measure_032_page1.png at position (1427, 2896) with confidence 1.00
# Matched measure_019_page1.png at position (823, 1946) with confidence 1.00
# Matched measure_021_page1.png at position (1919, 1900) with confidence 1.00
# Matched measure_014_page1.png at position (244, 1601) with confidence 1.00
# Matched measure_006_page1.png at position (220, 962) with confidence 1.00
# Matched measure_012_page1.png at position (1348, 1230) with confidence 1.00
# Matched measure_033_page1.png at position (1982, 3010) with confidence 1.00
# Matched measure_027_page1.png at position (859, 2587) with confidence 1.00
# Visualization saved to measures_pngs/How-Insensitive/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_003_page1.png to measure_002_page1.png
# Copied measure_004_page1.png to measure_003_page1.png
# Copied measure_005_page1.png to measure_004_page1.png
# Copied measure_006_page1.png to measure_005_page1.png
# Copied measure_007_page1.png to measure_006_page1.png
# Copied measure_008_page1.png to measure_007_page1.png
# Copied measure_009_page1.png to measure_008_page1.png
# Copied measure_010_page1.png to measure_009_page1.png
# Copied measure_011_page1.png to measure_010_page1.png
# Copied measure_012_page1.png to measure_011_page1.png
# Copied measure_013_page1.png to measure_012_page1.png
# Copied measure_014_page1.png to measure_013_page1.png
# Copied measure_015_page1.png to measure_014_page1.png
# Copied measure_016_page1.png to measure_015_page1.png
# Copied measure_017_page1.png to measure_016_page1.png
# Copied measure_018_page1.png to measure_017_page1.png
# Copied measure_019_page1.png to measure_018_page1.png
# Copied measure_020_page1.png to measure_019_page1.png
# Copied measure_021_page1.png to measure_020_page1.png
# Copied measure_022_page1.png to measure_021_page1.png
# Copied measure_023_page1.png to measure_022_page1.png
# Copied measure_024_page1.png to measure_023_page1.png
# Copied measure_025_page1.png to measure_024_page1.png
# Copied measure_026_page1.png to measure_025_page1.png
# Copied measure_027_page1.png to measure_026_page1.png
# Copied measure_028_page1.png to measure_027_page1.png
# Copied measure_029_page1.png to measure_028_page1.png
# Copied measure_030_page1.png to measure_029_page1.png
# Copied measure_031_page1.png to measure_030_page1.png
# Copied measure_032_page1.png to measure_031_page1.png
# Copied measure_033_page1.png to measure_032_page1.png
# Finished processing song folder: How-Insensitive
# Total measures: 32, Copied: 32
# Ordered measures saved to: measures_pngs/How-Insensitive/final_measures
#
# Processing song folder: Prelude-to-a-Kiss
# Created output directory: measures_pngs/Prelude-to-a-Kiss/final_measures
# Processing page 1 with sheet music: Prelude-to-a-Kiss_1.png
# Matched measure_017_page1.png at position (304, 1823) with confidence 1.00
# Matched measure_022_page1.png at position (881, 2142) with confidence 1.00
# Matched measure_008_page1.png at position (1747, 772) with confidence 1.00
# Matched measure_024_page1.png at position (1980, 2101) with confidence 1.00
# Matched measure_011_page1.png at position (1371, 1136) with confidence 1.00
# Matched measure_005_page1.png at position (1873, 455) with confidence 1.00
# Matched measure_002_page1.png at position (465, 513) with confidence 1.00
# Matched measure_016_page1.png at position (1950, 1456) with confidence 1.00
# Matched measure_023_page1.png at position (1421, 2110) with confidence 1.00
# Matched measure_028_page1.png at position (1988, 2438) with confidence 1.00
# Matched measure_009_page1.png at position (256, 1171) with confidence 1.00
# Matched measure_025_page1.png at position (331, 2441) with confidence 1.00
# Matched measure_004_page1.png at position (1251, 486) with confidence 1.00
# Matched measure_010_page1.png at position (851, 1149) with confidence 1.00
# Matched measure_018_page1.png at position (870, 1801) with confidence 1.00
# Matched measure_020_page1.png at position (1959, 1771) with confidence 1.00
# Matched measure_015_page1.png at position (1405, 1457) with confidence 1.00
# Matched measure_013_page1.png at position (279, 1491) with confidence 1.00
# Matched measure_007_page1.png at position (1031, 833) with confidence 1.00
# Matched measure_026_page1.png at position (890, 2438) with confidence 1.00
# Matched measure_019_page1.png at position (1415, 1778) with confidence 1.00
# Matched measure_021_page1.png at position (302, 2161) with confidence 1.00
# Matched measure_014_page1.png at position (862, 1458) with confidence 1.00
# Matched measure_006_page1.png at position (270, 864) with confidence 1.00
# Matched measure_012_page1.png at position (1940, 1135) with confidence 1.00
# Matched measure_027_page1.png at position (1438, 2432) with confidence 1.00
# Visualization saved to measures_pngs/Prelude-to-a-Kiss/new_visualizations/ordering_page1.png
# Copied measure_002_page1.png to measure_001_page1.png
# Copied measure_004_page1.png to measure_002_page1.png
# Copied measure_005_page1.png to measure_003_page1.png
# Copied measure_006_page1.png to measure_004_page1.png
# Copied measure_007_page1.png to measure_005_page1.png
# Copied measure_008_page1.png to measure_006_page1.png
# Copied measure_009_page1.png to measure_007_page1.png
# Copied measure_010_page1.png to measure_008_page1.png
# Copied measure_011_page1.png to measure_009_page1.png
# Copied measure_012_page1.png to measure_010_page1.png
# Copied measure_013_page1.png to measure_011_page1.png
# Copied measure_014_page1.png to measure_012_page1.png
# Copied measure_015_page1.png to measure_013_page1.png
# Copied measure_016_page1.png to measure_014_page1.png
# Copied measure_017_page1.png to measure_015_page1.png
# Copied measure_018_page1.png to measure_016_page1.png
# Copied measure_019_page1.png to measure_017_page1.png
# Copied measure_020_page1.png to measure_018_page1.png
# Copied measure_021_page1.png to measure_019_page1.png
# Copied measure_022_page1.png to measure_020_page1.png
# Copied measure_023_page1.png to measure_021_page1.png
# Copied measure_024_page1.png to measure_022_page1.png
# Copied measure_025_page1.png to measure_023_page1.png
# Copied measure_026_page1.png to measure_024_page1.png
# Copied measure_027_page1.png to measure_025_page1.png
# Copied measure_028_page1.png to measure_026_page1.png
# Finished processing song folder: Prelude-to-a-Kiss
# Total measures: 26, Copied: 26
# Ordered measures saved to: measures_pngs/Prelude-to-a-Kiss/final_measures
#
# Processing song folder: Do-You-Know-What-It-Means-To-Means-New-Orleans
# Created output directory: measures_pngs/Do-You-Know-What-It-Means-To-Means-New-Orleans/final_measures
# Processing page 1 with sheet music: Do-You-Know-What-It-Means-To-Means-New-Orleans_1.png
# Matched measure_017_page1.png at position (1265, 1409) with confidence 1.00
# Matched measure_036_page1.png at position (1625, 2586) with confidence 1.00
# Matched measure_029_page1.png at position (131, 2345) with confidence 1.00
# Matched measure_008_page1.png at position (1627, 811) with confidence 1.00
# Matched measure_024_page1.png at position (1813, 1717) with confidence 0.60 (scale: 0.36)
# Matched measure_011_page1.png at position (692, 1157) with confidence 1.00
# Matched measure_005_page1.png at position (1710, 508) with confidence 1.00
# Matched measure_002_page1.png at position (445, 538) with confidence 0.90 (scale: 0.52)
# Matched measure_016_page1.png at position (686, 1409) with confidence 1.00
# Matched measure_009_page1.png at position (157, 1175) with confidence 0.51 (scale: 0.29)
# Matched measure_031_page1.png at position (905, 2321) with confidence 1.00
# Matched measure_025_page1.png at position (138, 2031) with confidence 1.00
# Matched measure_004_page1.png at position (1086, 532) with confidence 1.00
# Matched measure_018_page1.png at position (1828, 1402) with confidence 1.00
# Matched measure_020_page1.png at position (705, 1709) with confidence 1.00
# Matched measure_034_page1.png at position (130, 2608) with confidence 1.00
# Matched measure_001_page1.png at position (294, 631) with confidence 0.67 (scale: 0.26)
# Matched measure_013_page1.png at position (1833, 1134) with confidence 1.00
# Matched measure_007_page1.png at position (875, 827) with confidence 0.84 (scale: 0.85)
# Matched measure_026_page1.png at position (878, 2008) with confidence 1.00
# Matched measure_019_page1.png at position (118, 1723) with confidence 0.85 (scale: 0.85)
# Matched measure_035_page1.png at position (876, 2626) with confidence 0.62 (scale: 0.42)
# Matched measure_021_page1.png at position (1270, 1729) with confidence 1.00
# Matched measure_014_page1.png at position (127, 1421) with confidence 1.00
# Matched measure_006_page1.png at position (114, 830) with confidence 1.00
# Matched measure_012_page1.png at position (1243, 1140) with confidence 0.83 (scale: 0.85)
# Matched measure_033_page1.png at position (1634, 2331) with confidence 0.89 (scale: 0.39)
# Matched measure_027_page1.png at position (1625, 2009) with confidence 1.00
# Visualization saved to measures_pngs/Do-You-Know-What-It-Means-To-Means-New-Orleans/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_004_page1.png to measure_003_page1.png
# Copied measure_005_page1.png to measure_004_page1.png
# Copied measure_006_page1.png to measure_005_page1.png
# Copied measure_007_page1.png to measure_006_page1.png
# Copied measure_008_page1.png to measure_007_page1.png
# Copied measure_009_page1.png to measure_008_page1.png
# Copied measure_011_page1.png to measure_009_page1.png
# Copied measure_012_page1.png to measure_010_page1.png
# Copied measure_013_page1.png to measure_011_page1.png
# Copied measure_014_page1.png to measure_012_page1.png
# Copied measure_016_page1.png to measure_013_page1.png
# Copied measure_017_page1.png to measure_014_page1.png
# Copied measure_018_page1.png to measure_015_page1.png
# Copied measure_019_page1.png to measure_016_page1.png
# Copied measure_020_page1.png to measure_017_page1.png
# Copied measure_021_page1.png to measure_018_page1.png
# Copied measure_024_page1.png to measure_019_page1.png
# Copied measure_025_page1.png to measure_020_page1.png
# Copied measure_026_page1.png to measure_021_page1.png
# Copied measure_027_page1.png to measure_022_page1.png
# Copied measure_029_page1.png to measure_023_page1.png
# Copied measure_031_page1.png to measure_024_page1.png
# Copied measure_033_page1.png to measure_025_page1.png
# Copied measure_034_page1.png to measure_026_page1.png
# Copied measure_035_page1.png to measure_027_page1.png
# Copied measure_036_page1.png to measure_028_page1.png
# Finished processing song folder: Do-You-Know-What-It-Means-To-Means-New-Orleans
# Total measures: 28, Copied: 28
# Ordered measures saved to: measures_pngs/Do-You-Know-What-It-Means-To-Means-New-Orleans/final_measures
#
# Processing song folder: I-Mean-You
# Created output directory: measures_pngs/I-Mean-You/final_measures
# Processing page 1 with sheet music: I-Mean-You_1.png
# Matched measure_017_page1.png at position (1353, 1973) with confidence 1.00
# Matched measure_003_page1.png at position (1399, 319) with confidence 1.00
# Matched measure_022_page1.png at position (822, 2324) with confidence 1.00
# Matched measure_008_page1.png at position (225, 1351) with confidence 1.00
# Matched measure_024_page1.png at position (1917, 2254) with confidence 1.00
# Matched measure_011_page1.png at position (1720, 1272) with confidence 1.00
# Matched measure_005_page1.png at position (208, 843) with confidence 1.00
# Matched measure_002_page1.png at position (805, 356) with confidence 1.00
# Matched measure_016_page1.png at position (1348, 1732) with confidence 1.00
# Matched measure_023_page1.png at position (1363, 2285) with confidence 1.00
# Matched measure_028_page1.png at position (1937, 2739) with confidence 1.00
# Matched measure_009_page1.png at position (1016, 1258) with confidence 1.00
# Matched measure_025_page1.png at position (284, 2848) with confidence 1.00
# Matched measure_004_page1.png at position (1887, 295) with confidence 1.00
# Matched measure_010_page1.png at position (1016, 1244) with confidence 1.00
# Matched measure_018_page1.png at position (1354, 1719) with confidence 1.00
# Matched measure_020_page1.png at position (1900, 1980) with confidence 1.00
# Matched measure_015_page1.png at position (801, 2033) with confidence 1.00
# Matched measure_001_page1.png at position (188, 227) with confidence 1.00
# Matched measure_013_page1.png at position (264, 2029) with confidence 1.00
# Matched measure_007_page1.png at position (1715, 802) with confidence 1.00
# Matched measure_026_page1.png at position (848, 2814) with confidence 1.00
# Matched measure_019_page1.png at position (1891, 1718) with confidence 1.00
# Matched measure_021_page1.png at position (254, 2354) with confidence 1.00
# Matched measure_014_page1.png at position (792, 1775) with confidence 1.00
# Matched measure_006_page1.png at position (992, 827) with confidence 1.00
# Matched measure_012_page1.png at position (235, 1794) with confidence 1.00
# Matched measure_027_page1.png at position (1387, 2775) with confidence 1.00
# Visualization saved to measures_pngs/I-Mean-You/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_004_page1.png to measure_004_page1.png
# Copied measure_005_page1.png to measure_005_page1.png
# Copied measure_006_page1.png to measure_006_page1.png
# Copied measure_007_page1.png to measure_007_page1.png
# Copied measure_008_page1.png to measure_008_page1.png
# Copied measure_009_page1.png to measure_009_page1.png
# Copied measure_010_page1.png to measure_010_page1.png
# Copied measure_011_page1.png to measure_011_page1.png
# Copied measure_012_page1.png to measure_012_page1.png
# Copied measure_014_page1.png to measure_013_page1.png
# Copied measure_016_page1.png to measure_014_page1.png
# Copied measure_018_page1.png to measure_015_page1.png
# Copied measure_019_page1.png to measure_016_page1.png
# Copied measure_013_page1.png to measure_017_page1.png
# Copied measure_015_page1.png to measure_018_page1.png
# Copied measure_017_page1.png to measure_019_page1.png
# Copied measure_020_page1.png to measure_020_page1.png
# Copied measure_021_page1.png to measure_021_page1.png
# Copied measure_022_page1.png to measure_022_page1.png
# Copied measure_023_page1.png to measure_023_page1.png
# Copied measure_024_page1.png to measure_024_page1.png
# Copied measure_025_page1.png to measure_025_page1.png
# Copied measure_026_page1.png to measure_026_page1.png
# Copied measure_027_page1.png to measure_027_page1.png
# Copied measure_028_page1.png to measure_028_page1.png
# Finished processing song folder: I-Mean-You
# Total measures: 28, Copied: 28
# Ordered measures saved to: measures_pngs/I-Mean-You/final_measures
#
# Processing song folder: Early-Autumn
# Created output directory: measures_pngs/Early-Autumn/final_measures
# Processing page 1 with sheet music: Early-Autumn_1.png
# Matched measure_017_page1.png at position (1499, 1704) with confidence 1.00
# Matched measure_003_page1.png at position (1556, 496) with confidence 0.83 (scale: 0.85)
# Matched measure_029_page1.png at position (1589, 2632) with confidence 1.00
# Matched measure_008_page1.png at position (162, 1112) with confidence 1.00
# Matched measure_024_page1.png at position (169, 2292) with confidence 1.00
# Matched measure_011_page1.png at position (1835, 1132) with confidence 1.00
# Matched measure_005_page1.png at position (154, 799) with confidence 1.00
# Matched measure_002_page1.png at position (790, 500) with confidence 0.83 (scale: 0.85)
# Matched measure_016_page1.png at position (809, 1696) with confidence 1.00
# Matched measure_023_page1.png at position (1750, 1999) with confidence 1.00
# Matched measure_009_page1.png at position (895, 1129) with confidence 1.00
# Matched measure_010_page1.png at position (1285, 1093) with confidence 1.00
# Matched measure_111_page1.png at position (950, 2322) with confidence 0.87 (scale: 1.40)
# Matched measure_020_page1.png at position (700, 1980) with confidence 1.00
# Matched measure_015_page1.png at position (161, 1704) with confidence 1.00
# Matched measure_129_page1.png at position (1056, 2627) with confidence 0.90 (scale: 1.40)
# Matched measure_001_page1.png at position (394, 574) with confidence 0.89 (scale: 0.85)
# Matched measure_013_page1.png at position (842, 1391) with confidence 1.00
# Matched measure_007_page1.png at position (1644, 811) with confidence 1.00
# Matched measure_026_page1.png at position (1745, 2294) with confidence 1.00
# Matched measure_019_page1.png at position (168, 2011) with confidence 1.00
# Matched measure_021_page1.png at position (1176, 2006) with confidence 1.00
# Matched measure_014_page1.png at position (1567, 1401) with confidence 1.00
# Matched measure_006_page1.png at position (882, 804) with confidence 1.00
# Matched measure_012_page1.png at position (170, 1380) with confidence 1.00
# Matched measure_027_page1.png at position (167, 2598) with confidence 1.00
# Visualization saved to measures_pngs/Early-Autumn/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_005_page1.png to measure_004_page1.png
# Copied measure_006_page1.png to measure_005_page1.png
# Copied measure_007_page1.png to measure_006_page1.png
# Copied measure_008_page1.png to measure_007_page1.png
# Copied measure_009_page1.png to measure_008_page1.png
# Copied measure_010_page1.png to measure_009_page1.png
# Copied measure_011_page1.png to measure_010_page1.png
# Copied measure_012_page1.png to measure_011_page1.png
# Copied measure_013_page1.png to measure_012_page1.png
# Copied measure_014_page1.png to measure_013_page1.png
# Copied measure_015_page1.png to measure_014_page1.png
# Copied measure_016_page1.png to measure_015_page1.png
# Copied measure_017_page1.png to measure_016_page1.png
# Copied measure_019_page1.png to measure_017_page1.png
# Copied measure_020_page1.png to measure_018_page1.png
# Copied measure_021_page1.png to measure_019_page1.png
# Copied measure_023_page1.png to measure_020_page1.png
# Copied measure_024_page1.png to measure_021_page1.png
# Copied measure_111_page1.png to measure_022_page1.png
# Copied measure_026_page1.png to measure_023_page1.png
# Copied measure_027_page1.png to measure_024_page1.png
# Copied measure_129_page1.png to measure_025_page1.png
# Copied measure_029_page1.png to measure_026_page1.png
# Finished processing song folder: Early-Autumn
# Total measures: 26, Copied: 26
# Ordered measures saved to: measures_pngs/Early-Autumn/final_measures
#
# Processing song folder: I-Get-a-Kick-Out-of-You
# Created output directory: measures_pngs/I-Get-a-Kick-Out-of-You/final_measures
# Processing page 2 with sheet music: I-Get-a-Kick-Out-of-You_2.png
# Matched measure_058_page2.png at position (740, 1394) with confidence 0.94 (scale: 0.75)
# Matched measure_060_page2.png at position (1875, 1376) with confidence 1.00
# Matched measure_055_page2.png at position (1337, 1115) with confidence 1.00
# Matched measure_041_page2.png at position (763, 315) with confidence 1.00
# Matched measure_053_page2.png at position (174, 1085) with confidence 1.00
# Matched measure_047_page2.png at position (1881, 503) with confidence 1.00
# Matched measure_066_page2.png at position (760, 1998) with confidence 1.00
# Matched measure_059_page2.png at position (1317, 1370) with confidence 1.00
# Matched measure_061_page2.png at position (181, 1676) with confidence 1.00
# Matched measure_040_page2.png at position (186, 208) with confidence 1.00
# Matched measure_054_page2.png at position (748, 1069) with confidence 0.96 (scale: 1.59)
# Matched measure_046_page2.png at position (1323, 513) with confidence 1.00
# Matched measure_052_page2.png at position (1884, 824) with confidence 1.00
# Matched measure_067_page2.png at position (1324, 1999) with confidence 1.00
# Matched measure_057_page2.png at position (186, 1374) with confidence 1.00
# Matched measure_043_page2.png at position (1872, 188) with confidence 1.00
# Matched measure_062_page2.png at position (747, 1665) with confidence 1.00
# Matched measure_048_page2.png at position (182, 773) with confidence 1.00
# Matched measure_064_page2.png at position (1874, 1716) with confidence 1.00
# Matched measure_051_page2.png at position (1332, 825) with confidence 1.00
# Matched measure_045_page2.png at position (746, 578) with confidence 1.00
# Matched measure_042_page2.png at position (1315, 214) with confidence 1.00
# Matched measure_056_page2.png at position (1898, 1127) with confidence 1.00
# Matched measure_063_page2.png at position (1300, 1728) with confidence 1.00
# Matched measure_068_page2.png at position (1880, 2010) with confidence 1.00
# Matched measure_049_page2.png at position (752, 892) with confidence 1.00
# Matched measure_065_page2.png at position (179, 1984) with confidence 1.00
# Matched measure_044_page2.png at position (187, 485) with confidence 1.00
# Visualization saved to measures_pngs/I-Get-a-Kick-Out-of-You/new_visualizations/ordering_page2.png
# Processing page 1 with sheet music: I-Get-a-Kick-Out-of-You_1.png
# Matched measure_017_page1.png at position (1839, 1336) with confidence 1.00
# Matched measure_003_page1.png at position (713, 401) with confidence 1.00
# Matched measure_022_page1.png at position (138, 1907) with confidence 1.00
# Matched measure_036_page1.png at position (134, 2785) with confidence 1.00
# Matched measure_029_page1.png at position (718, 2192) with confidence 1.00
# Matched measure_008_page1.png at position (1260, 715) with confidence 1.00
# Matched measure_024_page1.png at position (709, 1910) with confidence 1.00
# Matched measure_030_page1.png at position (1294, 2224) with confidence 1.00
# Matched measure_011_page1.png at position (703, 1012) with confidence 1.00
# Matched measure_005_page1.png at position (1749, 408) with confidence 1.00
# Matched measure_016_page1.png at position (1285, 1319) with confidence 1.00
# Matched measure_037_page1.png at position (709, 2866) with confidence 1.00
# Matched measure_028_page1.png at position (131, 2189) with confidence 1.00
# Matched measure_009_page1.png at position (1852, 706) with confidence 1.00
# Matched measure_031_page1.png at position (1870, 2205) with confidence 1.00
# Matched measure_004_page1.png at position (1230, 403) with confidence 1.00
# Matched measure_010_page1.png at position (136, 1003) with confidence 1.00
# Matched measure_039_page1.png at position (1839, 2927) with confidence 1.00
# Matched measure_018_page1.png at position (139, 1603) with confidence 1.00
# Matched measure_020_page1.png at position (1280, 1600) with confidence 1.00
# Matched measure_034_page1.png at position (1285, 2501) with confidence 1.00
# Matched measure_015_page1.png at position (713, 1328) with confidence 1.00
# Matched measure_001_page1.png at position (360, 379) with confidence 0.90 (scale: 1.33)
# Matched measure_013_page1.png at position (1835, 1036) with confidence 1.00
# Matched measure_007_page1.png at position (710, 687) with confidence 1.00
# Matched measure_026_page1.png at position (1274, 1906) with confidence 1.00
# Matched measure_032_page1.png at position (130, 2521) with confidence 1.00
# Matched measure_038_page1.png at position (1278, 2884) with confidence 1.00
# Matched measure_019_page1.png at position (712, 1614) with confidence 1.00
# Matched measure_035_page1.png at position (1847, 2633) with confidence 1.00
# Matched measure_021_page1.png at position (1846, 1629) with confidence 1.00
# Matched measure_014_page1.png at position (135, 1305) with confidence 1.00
# Matched measure_006_page1.png at position (137, 712) with confidence 1.00
# Matched measure_012_page1.png at position (1263, 1041) with confidence 1.00
# Matched measure_033_page1.png at position (722, 2500) with confidence 1.00
# Matched measure_027_page1.png at position (1859, 1904) with confidence 1.00
# Visualization saved to measures_pngs/I-Get-a-Kick-Out-of-You/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_003_page1.png to measure_002_page1.png
# Copied measure_004_page1.png to measure_003_page1.png
# Copied measure_005_page1.png to measure_004_page1.png
# Copied measure_006_page1.png to measure_005_page1.png
# Copied measure_007_page1.png to measure_006_page1.png
# Copied measure_008_page1.png to measure_007_page1.png
# Copied measure_009_page1.png to measure_008_page1.png
# Copied measure_010_page1.png to measure_009_page1.png
# Copied measure_011_page1.png to measure_010_page1.png
# Copied measure_012_page1.png to measure_011_page1.png
# Copied measure_013_page1.png to measure_012_page1.png
# Copied measure_014_page1.png to measure_013_page1.png
# Copied measure_015_page1.png to measure_014_page1.png
# Copied measure_016_page1.png to measure_015_page1.png
# Copied measure_017_page1.png to measure_016_page1.png
# Copied measure_018_page1.png to measure_017_page1.png
# Copied measure_019_page1.png to measure_018_page1.png
# Copied measure_020_page1.png to measure_019_page1.png
# Copied measure_021_page1.png to measure_020_page1.png
# Copied measure_022_page1.png to measure_021_page1.png
# Copied measure_024_page1.png to measure_022_page1.png
# Copied measure_026_page1.png to measure_023_page1.png
# Copied measure_027_page1.png to measure_024_page1.png
# Copied measure_028_page1.png to measure_025_page1.png
# Copied measure_029_page1.png to measure_026_page1.png
# Copied measure_030_page1.png to measure_027_page1.png
# Copied measure_031_page1.png to measure_028_page1.png
# Copied measure_032_page1.png to measure_029_page1.png
# Copied measure_033_page1.png to measure_030_page1.png
# Copied measure_034_page1.png to measure_031_page1.png
# Copied measure_035_page1.png to measure_032_page1.png
# Copied measure_036_page1.png to measure_033_page1.png
# Copied measure_037_page1.png to measure_034_page1.png
# Copied measure_038_page1.png to measure_035_page1.png
# Copied measure_039_page1.png to measure_036_page1.png
# Copied measure_040_page2.png to measure_037_page2.png
# Copied measure_041_page2.png to measure_038_page2.png
# Copied measure_042_page2.png to measure_039_page2.png
# Copied measure_043_page2.png to measure_040_page2.png
# Copied measure_044_page2.png to measure_041_page2.png
# Copied measure_045_page2.png to measure_042_page2.png
# Copied measure_046_page2.png to measure_043_page2.png
# Copied measure_047_page2.png to measure_044_page2.png
# Copied measure_048_page2.png to measure_045_page2.png
# Copied measure_049_page2.png to measure_046_page2.png
# Copied measure_051_page2.png to measure_047_page2.png
# Copied measure_052_page2.png to measure_048_page2.png
# Copied measure_053_page2.png to measure_049_page2.png
# Copied measure_054_page2.png to measure_050_page2.png
# Copied measure_055_page2.png to measure_051_page2.png
# Copied measure_056_page2.png to measure_052_page2.png
# Copied measure_057_page2.png to measure_053_page2.png
# Copied measure_058_page2.png to measure_054_page2.png
# Copied measure_059_page2.png to measure_055_page2.png
# Copied measure_060_page2.png to measure_056_page2.png
# Copied measure_061_page2.png to measure_057_page2.png
# Copied measure_062_page2.png to measure_058_page2.png
# Copied measure_063_page2.png to measure_059_page2.png
# Copied measure_064_page2.png to measure_060_page2.png
# Copied measure_065_page2.png to measure_061_page2.png
# Copied measure_066_page2.png to measure_062_page2.png
# Copied measure_067_page2.png to measure_063_page2.png
# Copied measure_068_page2.png to measure_064_page2.png
# Finished processing song folder: I-Get-a-Kick-Out-of-You
# Total measures: 64, Copied: 64
# Ordered measures saved to: measures_pngs/I-Get-a-Kick-Out-of-You/final_measures
#
# Processing song folder: Minor-Mood
# Created output directory: measures_pngs/Minor-Mood/final_measures
# Processing page 1 with sheet music: Minor-Mood_1.png
# Matched measure_041_page1.png at position (1032, 2867) with confidence 0.93 (scale: 1.75)
# Matched measure_017_page1.png at position (1056, 1706) with confidence 1.00
# Matched measure_003_page1.png at position (131, 779) with confidence 1.00
# Matched measure_022_page1.png at position (456, 1996) with confidence 1.00
# Matched measure_036_page1.png at position (1232, 2560) with confidence 1.00
# Matched measure_029_page1.png at position (124, 2269) with confidence 1.00
# Matched measure_008_page1.png at position (857, 1082) with confidence 1.00
# Matched measure_024_page1.png at position (1097, 2013) with confidence 1.00
# Matched measure_030_page1.png at position (710, 2261) with confidence 1.00
# Matched measure_011_page1.png at position (693, 1374) with confidence 1.00
# Matched measure_005_page1.png at position (1623, 786) with confidence 1.00
# Matched measure_040_page1.png at position (667, 2885) with confidence 0.94 (scale: 1.75)
# Matched measure_002_page1.png at position (699, 477) with confidence 0.93 (scale: 1.75)
# Matched measure_016_page1.png at position (759, 1700) with confidence 1.00
# Matched measure_023_page1.png at position (777, 1997) with confidence 1.00
# Matched measure_028_page1.png at position (2043, 1999) with confidence 1.00
# Matched measure_009_page1.png at position (1659, 1096) with confidence 1.00
# Matched measure_004_page1.png at position (872, 773) with confidence 1.00
# Matched measure_010_page1.png at position (128, 1362) with confidence 1.00
# Matched measure_0302_page1.png at position (1825, 2257) with confidence 0.94 (scale: 1.75)
# Matched measure_039_page1.png at position (122, 2885) with confidence 1.00
# Matched measure_043_page1.png at position (1639, 2878) with confidence 0.95 (scale: 1.75)
# Matched measure_0021_page1.png at position (1516, 446) with confidence 0.93 (scale: 1.75)
# Matched measure_018_page1.png at position (1371, 1724) with confidence 1.00
# Matched measure_020_page1.png at position (2038, 1708) with confidence 1.00
# Matched measure_034_page1.png at position (678, 2559) with confidence 0.93 (scale: 1.75)
# Matched measure_015_page1.png at position (463, 1714) with confidence 1.00
# Matched measure_001_page1.png at position (456, 551) with confidence 0.95 (scale: 1.75)
# Matched measure_013_page1.png at position (1798, 1373) with confidence 1.00
# Matched measure_0301_page1.png at position (1267, 2264) with confidence 0.95 (scale: 1.75)
# Matched measure_026_page1.png at position (1420, 2009) with confidence 1.00
# Matched measure_038_page1.png at position (1823, 2585) with confidence 1.00
# Matched measure_042_page1.png at position (1344, 2923) with confidence 0.95 (scale: 1.75)
# Matched measure_019_page1.png at position (1701, 1695) with confidence 1.00
# Matched measure_021_page1.png at position (123, 2005) with confidence 1.00
# Matched measure_014_page1.png at position (134, 1680) with confidence 1.00
# Matched measure_044_page1.png at position (2018, 2885) with confidence 0.93 (scale: 1.75)
# Matched measure_006_page1.png at position (126, 1066) with confidence 1.00
# Matched measure_012_page1.png at position (1234, 1355) with confidence 1.00
# Matched measure_033_page1.png at position (126, 2583) with confidence 1.00
# Matched measure_027_page1.png at position (1719, 2009) with confidence 1.00
# Visualization saved to measures_pngs/Minor-Mood/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_0021_page1.png to measure_003_page1.png
# Copied measure_003_page1.png to measure_004_page1.png
# Copied measure_004_page1.png to measure_005_page1.png
# Copied measure_005_page1.png to measure_006_page1.png
# Copied measure_006_page1.png to measure_007_page1.png
# Copied measure_008_page1.png to measure_008_page1.png
# Copied measure_009_page1.png to measure_009_page1.png
# Copied measure_010_page1.png to measure_010_page1.png
# Copied measure_011_page1.png to measure_011_page1.png
# Copied measure_012_page1.png to measure_012_page1.png
# Copied measure_013_page1.png to measure_013_page1.png
# Copied measure_014_page1.png to measure_014_page1.png
# Copied measure_015_page1.png to measure_015_page1.png
# Copied measure_016_page1.png to measure_016_page1.png
# Copied measure_017_page1.png to measure_017_page1.png
# Copied measure_018_page1.png to measure_018_page1.png
# Copied measure_019_page1.png to measure_019_page1.png
# Copied measure_020_page1.png to measure_020_page1.png
# Copied measure_021_page1.png to measure_021_page1.png
# Copied measure_022_page1.png to measure_022_page1.png
# Copied measure_023_page1.png to measure_023_page1.png
# Copied measure_024_page1.png to measure_024_page1.png
# Copied measure_026_page1.png to measure_025_page1.png
# Copied measure_027_page1.png to measure_026_page1.png
# Copied measure_028_page1.png to measure_027_page1.png
# Copied measure_029_page1.png to measure_028_page1.png
# Copied measure_030_page1.png to measure_029_page1.png
# Copied measure_0301_page1.png to measure_030_page1.png
# Copied measure_0302_page1.png to measure_031_page1.png
# Copied measure_033_page1.png to measure_032_page1.png
# Copied measure_034_page1.png to measure_033_page1.png
# Copied measure_036_page1.png to measure_034_page1.png
# Copied measure_038_page1.png to measure_035_page1.png
# Copied measure_039_page1.png to measure_036_page1.png
# Copied measure_040_page1.png to measure_037_page1.png
# Copied measure_041_page1.png to measure_038_page1.png
# Copied measure_042_page1.png to measure_039_page1.png
# Copied measure_043_page1.png to measure_040_page1.png
# Copied measure_044_page1.png to measure_041_page1.png
# Finished processing song folder: Minor-Mood
# Total measures: 41, Copied: 41
# Ordered measures saved to: measures_pngs/Minor-Mood/final_measures
#
# Processing song folder: When-I-fall-in-love
# Created output directory: measures_pngs/When-I-fall-in-love/final_measures
# Processing page 1 with sheet music: When-I-fall-in-love_1.png
# Matched measure_017_page1.png at position (254, 1911) with confidence 1.00
# Matched measure_003_page1.png at position (1369, 590) with confidence 1.00
# Matched measure_022_page1.png at position (846, 2253) with confidence 1.00
# Matched measure_008_page1.png at position (1930, 938) with confidence 1.00
# Matched measure_024_page1.png at position (1947, 2253) with confidence 1.00
# Matched measure_011_page1.png at position (1380, 1217) with confidence 1.00
# Matched measure_005_page1.png at position (265, 978) with confidence 1.00
# Matched measure_002_page1.png at position (835, 632) with confidence 1.00
# Matched measure_016_page1.png at position (1937, 1562) with confidence 1.00
# Matched measure_023_page1.png at position (1402, 2252) with confidence 1.00
# Matched measure_009_page1.png at position (245, 1245) with confidence 1.00
# Matched measure_004_page1.png at position (1922, 603) with confidence 1.00
# Matched measure_010_page1.png at position (840, 1256) with confidence 1.00
# Matched measure_018_page1.png at position (844, 1931) with confidence 1.00
# Matched measure_020_page1.png at position (1948, 1918) with confidence 1.00
# Matched measure_015_page1.png at position (1389, 1553) with confidence 1.00
# Matched measure_001_page1.png at position (185, 642) with confidence 1.00
# Matched measure_013_page1.png at position (276, 1577) with confidence 1.00
# Matched measure_007_page1.png at position (1376, 948) with confidence 1.00
# Matched measure_019_page1.png at position (1398, 1927) with confidence 1.00
# Matched measure_021_page1.png at position (283, 2217) with confidence 1.00
# Matched measure_014_page1.png at position (843, 1575) with confidence 1.00
# Matched measure_006_page1.png at position (838, 963) with confidence 1.00
# Matched measure_012_page1.png at position (1926, 1208) with confidence 1.00
# Visualization saved to measures_pngs/When-I-fall-in-love/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_004_page1.png to measure_004_page1.png
# Copied measure_005_page1.png to measure_005_page1.png
# Copied measure_006_page1.png to measure_006_page1.png
# Copied measure_007_page1.png to measure_007_page1.png
# Copied measure_008_page1.png to measure_008_page1.png
# Copied measure_009_page1.png to measure_009_page1.png
# Copied measure_010_page1.png to measure_010_page1.png
# Copied measure_011_page1.png to measure_011_page1.png
# Copied measure_012_page1.png to measure_012_page1.png
# Copied measure_013_page1.png to measure_013_page1.png
# Copied measure_014_page1.png to measure_014_page1.png
# Copied measure_015_page1.png to measure_015_page1.png
# Copied measure_016_page1.png to measure_016_page1.png
# Copied measure_017_page1.png to measure_017_page1.png
# Copied measure_018_page1.png to measure_018_page1.png
# Copied measure_019_page1.png to measure_019_page1.png
# Copied measure_020_page1.png to measure_020_page1.png
# Copied measure_021_page1.png to measure_021_page1.png
# Copied measure_022_page1.png to measure_022_page1.png
# Copied measure_023_page1.png to measure_023_page1.png
# Copied measure_024_page1.png to measure_024_page1.png
# Finished processing song folder: When-I-fall-in-love
# Total measures: 24, Copied: 24
# Ordered measures saved to: measures_pngs/When-I-fall-in-love/final_measures
#
# Processing song folder: Careless-Love
# Created output directory: measures_pngs/Careless-Love/final_measures
# Processing page 1 with sheet music: Careless-Love_1.png
# Matched measure_017_page1.png at position (85, 943) with confidence 1.00
# Matched measure_003_page1.png at position (516, 315) with confidence 1.00
# Matched measure_008_page1.png at position (817, 534) with confidence 1.00
# Matched measure_005_page1.png at position (1239, 311) with confidence 1.00
# Matched measure_002_page1.png at position (966, 738) with confidence 0.59 (scale: 0.23)
# Matched measure_009_page1.png at position (1231, 529) with confidence 1.00
# Matched measure_004_page1.png at position (876, 316) with confidence 1.00
# Matched measure_010_page1.png at position (85, 732) with confidence 1.00
# Matched measure_020_page1.png at position (942, 957) with confidence 1.00
# Matched measure_013_page1.png at position (871, 742) with confidence 1.00
# Matched measure_007_page1.png at position (419, 528) with confidence 1.00
# Matched measure_019_page1.png at position (477, 959) with confidence 1.00
# Matched measure_021_page1.png at position (1328, 949) with confidence 1.00
# Matched measure_014_page1.png at position (1252, 736) with confidence 1.00
# Matched measure_006_page1.png at position (85, 508) with confidence 1.00
# Matched measure_012_page1.png at position (457, 735) with confidence 1.00
# Visualization saved to measures_pngs/Careless-Love/new_visualizations/ordering_page1.png
# Copied measure_003_page1.png to measure_001_page1.png
# Copied measure_004_page1.png to measure_002_page1.png
# Copied measure_005_page1.png to measure_003_page1.png
# Copied measure_006_page1.png to measure_004_page1.png
# Copied measure_007_page1.png to measure_005_page1.png
# Copied measure_008_page1.png to measure_006_page1.png
# Copied measure_009_page1.png to measure_007_page1.png
# Copied measure_010_page1.png to measure_008_page1.png
# Copied measure_012_page1.png to measure_009_page1.png
# Copied measure_013_page1.png to measure_010_page1.png
# Copied measure_002_page1.png to measure_011_page1.png
# Copied measure_014_page1.png to measure_012_page1.png
# Copied measure_017_page1.png to measure_013_page1.png
# Copied measure_019_page1.png to measure_014_page1.png
# Copied measure_020_page1.png to measure_015_page1.png
# Copied measure_021_page1.png to measure_016_page1.png
# Finished processing song folder: Careless-Love
# Total measures: 16, Copied: 16
# Ordered measures saved to: measures_pngs/Careless-Love/final_measures
#
# Processing song folder: Cherokee
# Created output directory: measures_pngs/Cherokee/final_measures
# Processing page 1 with sheet music: Cherokee_1.png
# Matched measure_055_page1.png at position (1939, 3048) with confidence 1.00
# Matched measure_041_page1.png at position (525, 2523) with confidence 1.00
# Matched measure_003_page1.png at position (1035, 511) with confidence 1.00
# Matched measure_022_page1.png at position (1423, 1288) with confidence 1.00
# Matched measure_036_page1.png at position (99, 2235) with confidence 1.00
# Matched measure_029_page1.png at position (649, 1770) with confidence 1.00
# Matched measure_053_page1.png at position (1178, 3004) with confidence 1.00
# Matched measure_047_page1.png at position (955, 2778) with confidence 1.00
# Matched measure_008_page1.png at position (1025, 796) with confidence 1.00
# Matched measure_024_page1.png at position (95, 1545) with confidence 1.00
# Matched measure_030_page1.png at position (1193, 1779) with confidence 1.00
# Matched measure_011_page1.png at position (118, 1020) with confidence 1.00
# Matched measure_005_page1.png at position (1878, 515) with confidence 1.00
# Matched measure_040_page1.png at position (75, 2508) with confidence 1.00
# Matched measure_054_page1.png at position (1579, 3017) with confidence 1.00
# Matched measure_002_page1.png at position (624, 493) with confidence 1.00
# Matched measure_016_page1.png at position (115, 1251) with confidence 1.00
# Matched measure_037_page1.png at position (634, 2248) with confidence 1.00
# Matched measure_023_page1.png at position (1863, 1330) with confidence 1.00
# Matched measure_046_page1.png at position (516, 2759) with confidence 1.00
# Matched measure_028_page1.png at position (104, 1754) with confidence 1.00
# Matched measure_052_page1.png at position (818, 3007) with confidence 1.00
# Matched measure_009_page1.png at position (1438, 793) with confidence 1.00
# Matched measure_031_page1.png at position (1734, 1802) with confidence 1.00
# Matched measure_025_page1.png at position (649, 1536) with confidence 1.00
# Matched measure_004_page1.png at position (1445, 504) with confidence 1.00
# Matched measure_010_page1.png at position (1870, 815) with confidence 1.00
# Matched measure_039_page1.png at position (1731, 2273) with confidence 1.00
# Matched measure_043_page1.png at position (1396, 2549) with confidence 1.00
# Matched measure_020_page1.png at position (542, 1269) with confidence 1.00
# Matched measure_034_page1.png at position (1191, 2043) with confidence 1.00
# Matched measure_015_page1.png at position (1866, 1084) with confidence 1.00
# Matched measure_001_page1.png at position (252, 490) with confidence 0.66 (scale: 0.29)
# Matched measure_051_page1.png at position (466, 3008) with confidence 1.00
# Matched measure_045_page1.png at position (87, 2761) with confidence 1.00
# Matched measure_013_page1.png at position (1002, 1056) with confidence 1.00
# Matched measure_007_page1.png at position (558, 780) with confidence 1.00
# Matched measure_026_page1.png at position (1201, 1522) with confidence 1.00
# Matched measure_048_page1.png at position (1401, 2768) with confidence 1.00
# Matched measure_032_page1.png at position (96, 2009) with confidence 1.00
# Matched measure_038_page1.png at position (1190, 2263) with confidence 1.00
# Matched measure_042_page1.png at position (958, 2520) with confidence 1.00
# Matched measure_035_page1.png at position (1735, 2063) with confidence 1.00
# Matched measure_021_page1.png at position (1002, 1285) with confidence 1.00
# Matched measure_014_page1.png at position (1427, 1056) with confidence 1.00
# Matched measure_044_page1.png at position (1840, 2546) with confidence 1.00
# Matched measure_050_page1.png at position (86, 3005) with confidence 1.00
# Matched measure_006_page1.png at position (127, 759) with confidence 1.00
# Matched measure_012_page1.png at position (551, 1063) with confidence 1.00
# Matched measure_049_page1.png at position (1831, 2782) with confidence 1.00
# Matched measure_033_page1.png at position (644, 2019) with confidence 1.00
# Matched measure_027_page1.png at position (1739, 1576) with confidence 1.00
# Visualization saved to measures_pngs/Cherokee/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_004_page1.png to measure_004_page1.png
# Copied measure_005_page1.png to measure_005_page1.png
# Copied measure_006_page1.png to measure_006_page1.png
# Copied measure_007_page1.png to measure_007_page1.png
# Copied measure_008_page1.png to measure_008_page1.png
# Copied measure_009_page1.png to measure_009_page1.png
# Copied measure_010_page1.png to measure_010_page1.png
# Copied measure_011_page1.png to measure_011_page1.png
# Copied measure_012_page1.png to measure_012_page1.png
# Copied measure_013_page1.png to measure_013_page1.png
# Copied measure_014_page1.png to measure_014_page1.png
# Copied measure_015_page1.png to measure_015_page1.png
# Copied measure_016_page1.png to measure_016_page1.png
# Copied measure_020_page1.png to measure_017_page1.png
# Copied measure_021_page1.png to measure_018_page1.png
# Copied measure_022_page1.png to measure_019_page1.png
# Copied measure_023_page1.png to measure_020_page1.png
# Copied measure_024_page1.png to measure_021_page1.png
# Copied measure_025_page1.png to measure_022_page1.png
# Copied measure_026_page1.png to measure_023_page1.png
# Copied measure_027_page1.png to measure_024_page1.png
# Copied measure_028_page1.png to measure_025_page1.png
# Copied measure_029_page1.png to measure_026_page1.png
# Copied measure_030_page1.png to measure_027_page1.png
# Copied measure_031_page1.png to measure_028_page1.png
# Copied measure_032_page1.png to measure_029_page1.png
# Copied measure_033_page1.png to measure_030_page1.png
# Copied measure_034_page1.png to measure_031_page1.png
# Copied measure_035_page1.png to measure_032_page1.png
# Copied measure_036_page1.png to measure_033_page1.png
# Copied measure_037_page1.png to measure_034_page1.png
# Copied measure_038_page1.png to measure_035_page1.png
# Copied measure_039_page1.png to measure_036_page1.png
# Copied measure_040_page1.png to measure_037_page1.png
# Copied measure_041_page1.png to measure_038_page1.png
# Copied measure_042_page1.png to measure_039_page1.png
# Copied measure_043_page1.png to measure_040_page1.png
# Copied measure_044_page1.png to measure_041_page1.png
# Copied measure_045_page1.png to measure_042_page1.png
# Copied measure_046_page1.png to measure_043_page1.png
# Copied measure_047_page1.png to measure_044_page1.png
# Copied measure_048_page1.png to measure_045_page1.png
# ...
# Matched measure_007_page1.png at position (1358, 861) with confidence 1.00
# Matched measure_026_page1.png at position (844, 2486) with confidence 1.00
# Matched measure_032_page1.png at position (1943, 2795) with confidence 1.00
# Matched measure_019_page1.png at position (1373, 1826) with confidence 1.00
# Matched measure_021_page1.png at position (263, 2179) with confidence 1.00
# Matched measure_000_page1.png at position (358, 633) with confidence 0.95 (scale: 1.75)
# Matched measure_014_page1.png at position (822, 1506) with confidence 1.00
# Matched measure_006_page1.png at position (809, 878) with confidence 1.00
# Matched measure_012_page1.png at position (1914, 1155) with confidence 1.00
# Matched measure_027_page1.png at position (1392, 2493) with confidence 1.00
# Visualization saved to measures_pngs/There-Is-No-Greater-Love/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_004_page1.png to measure_004_page1.png
# Copied measure_000_page1.png to measure_005_page1.png
# Copied measure_005_page1.png to measure_006_page1.png
# Copied measure_006_page1.png to measure_007_page1.png
# Copied measure_007_page1.png to measure_008_page1.png
# Copied measure_008_page1.png to measure_009_page1.png
# Copied measure_009_page1.png to measure_010_page1.png
# Copied measure_010_page1.png to measure_011_page1.png
# Copied measure_011_page1.png to measure_012_page1.png
# Copied measure_012_page1.png to measure_013_page1.png
# Copied measure_013_page1.png to measure_014_page1.png
# Copied measure_014_page1.png to measure_015_page1.png
# Copied measure_015_page1.png to measure_016_page1.png
# Copied measure_016_page1.png to measure_017_page1.png
# Copied measure_017_page1.png to measure_018_page1.png
# Copied measure_018_page1.png to measure_019_page1.png
# Copied measure_019_page1.png to measure_020_page1.png
# Copied measure_020_page1.png to measure_021_page1.png
# Copied measure_021_page1.png to measure_022_page1.png
# Copied measure_022_page1.png to measure_023_page1.png
# Copied measure_023_page1.png to measure_024_page1.png
# Copied measure_024_page1.png to measure_025_page1.png
# Copied measure_025_page1.png to measure_026_page1.png
# Copied measure_026_page1.png to measure_027_page1.png
# Copied measure_027_page1.png to measure_028_page1.png
# Copied measure_028_page1.png to measure_029_page1.png
# Copied measure_029_page1.png to measure_030_page1.png
# Copied measure_030_page1.png to measure_031_page1.png
# Copied measure_031_page1.png to measure_032_page1.png
# Copied measure_032_page1.png to measure_033_page1.png
# Finished processing song folder: There-Is-No-Greater-Love
# Total measures: 33, Copied: 33
# Ordered measures saved to: measures_pngs/There-Is-No-Greater-Love/final_measures
#
# Processing song folder: Fools-Rush-In
# Created output directory: measures_pngs/Fools-Rush-In/final_measures
# Processing page 1 with sheet music: Fools-Rush-In_1.png
# Matched measure_017_page1.png at position (1934, 1519) with confidence 1.00
# Matched measure_003_page1.png at position (1507, 626) with confidence 1.00
# Matched measure_022_page1.png at position (243, 2112) with confidence 1.00
# Matched measure_036_page1.png at position (238, 2975) with confidence 1.00
# Matched measure_029_page1.png at position (1923, 2420) with confidence 1.00
# Matched measure_008_page1.png at position (1931, 944) with confidence 1.00
# Matched measure_024_page1.png at position (1367, 2112) with confidence 1.00
# Matched measure_030_page1.png at position (233, 2718) with confidence 1.00
# Matched measure_011_page1.png at position (1370, 1230) with confidence 1.00
# Matched measure_005_page1.png at position (242, 897) with confidence 1.00
# Matched measure_002_page1.png at position (990, 595) with confidence 1.00
# Matched measure_016_page1.png at position (1375, 1514) with confidence 1.00
# Matched measure_037_page1.png at position (732, 3100) with confidence 1.00
# Matched measure_023_page1.png at position (798, 2097) with confidence 1.00
# Matched measure_028_page1.png at position (1359, 2419) with confidence 1.00
# Matched measure_009_page1.png at position (230, 1242) with confidence 1.00
# Matched measure_031_page1.png at position (222, 2704) with confidence 1.00
# Matched measure_025_page1.png at position (1937, 2120) with confidence 1.00
# Matched measure_004_page1.png at position (1988, 598) with confidence 1.00
# Matched measure_010_page1.png at position (805, 1204) with confidence 1.00
# Matched measure_018_page1.png at position (245, 1789) with confidence 1.00
# Matched measure_020_page1.png at position (1373, 1834) with confidence 1.00
# Matched measure_034_page1.png at position (1915, 2714) with confidence 1.00
# Matched measure_015_page1.png at position (818, 1508) with confidence 1.00
# Matched measure_001_page1.png at position (481, 587) with confidence 0.90 (scale: 0.75)
# Matched measure_013_page1.png at position (230, 1238) with confidence 1.00
# Matched measure_007_page1.png at position (1364, 934) with confidence 1.00
# Matched measure_026_page1.png at position (222, 2416) with confidence 1.00
# Matched measure_032_page1.png at position (815, 2699) with confidence 1.00
# Matched measure_038_page1.png at position (1224, 3111) with confidence 1.00
# Matched measure_019_page1.png at position (809, 1788) with confidence 1.00
# Matched measure_035_page1.png at position (1920, 2713) with confidence 1.00
# Matched measure_021_page1.png at position (1942, 1795) with confidence 1.00
# Matched measure_014_page1.png at position (235, 1494) with confidence 1.00
# Matched measure_006_page1.png at position (817, 917) with confidence 1.00
# Matched measure_012_page1.png at position (1932, 1214) with confidence 1.00
# Matched measure_033_page1.png at position (1364, 2692) with confidence 1.00
# Matched measure_027_page1.png at position (797, 2395) with confidence 1.00
# Visualization saved to measures_pngs/Fools-Rush-In/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_004_page1.png to measure_004_page1.png
# Copied measure_005_page1.png to measure_005_page1.png
# Copied measure_006_page1.png to measure_006_page1.png
# Copied measure_007_page1.png to measure_007_page1.png
# Copied measure_008_page1.png to measure_008_page1.png
# Copied measure_009_page1.png to measure_009_page1.png
# Copied measure_010_page1.png to measure_010_page1.png
# Copied measure_011_page1.png to measure_011_page1.png
# Copied measure_012_page1.png to measure_012_page1.png
# Copied measure_013_page1.png to measure_013_page1.png
# Copied measure_014_page1.png to measure_014_page1.png
# Copied measure_015_page1.png to measure_015_page1.png
# Copied measure_016_page1.png to measure_016_page1.png
# Copied measure_017_page1.png to measure_017_page1.png
# Copied measure_018_page1.png to measure_018_page1.png
# Copied measure_019_page1.png to measure_019_page1.png
# Copied measure_020_page1.png to measure_020_page1.png
# Copied measure_021_page1.png to measure_021_page1.png
# Copied measure_022_page1.png to measure_022_page1.png
# Copied measure_023_page1.png to measure_023_page1.png
# Copied measure_024_page1.png to measure_024_page1.png
# Copied measure_025_page1.png to measure_025_page1.png
# Copied measure_026_page1.png to measure_026_page1.png
# Copied measure_027_page1.png to measure_027_page1.png
# Copied measure_028_page1.png to measure_028_page1.png
# Copied measure_029_page1.png to measure_029_page1.png
# Copied measure_031_page1.png to measure_030_page1.png
# Copied measure_032_page1.png to measure_031_page1.png
# Copied measure_033_page1.png to measure_032_page1.png
# Copied measure_034_page1.png to measure_033_page1.png
# Copied measure_035_page1.png to measure_034_page1.png
# Copied measure_030_page1.png to measure_035_page1.png
# Copied measure_036_page1.png to measure_036_page1.png
# Copied measure_037_page1.png to measure_037_page1.png
# Copied measure_038_page1.png to measure_038_page1.png
# Finished processing song folder: Fools-Rush-In
# Total measures: 38, Copied: 38
# Ordered measures saved to: measures_pngs/Fools-Rush-In/final_measures
#
# Processing song folder: They-Cant-Take-That-Away-From-Me
# Created output directory: measures_pngs/They-Cant-Take-That-Away-From-Me/final_measures
# Processing page 1 with sheet music: They-Cant-Take-That-Away-From-Me_1.png
# Matched measure_017_page1.png at position (1407, 1482) with confidence 1.00
# Matched measure_003_page1.png at position (822, 519) with confidence 1.00
# Matched measure_022_page1.png at position (1965, 1810) with confidence 1.00
# Matched measure_029_page1.png at position (1434, 2437) with confidence 1.00
# Matched measure_008_page1.png at position (845, 852) with confidence 1.00
# Matched measure_024_page1.png at position (875, 2149) with confidence 1.00
# Matched measure_030_page1.png at position (1986, 2434) with confidence 1.00
# Matched measure_011_page1.png at position (265, 1143) with confidence 1.00
# Matched measure_005_page1.png at position (1711, 496) with confidence 1.00
# Matched measure_002_page1.png at position (254, 508) with confidence 1.00
# Matched measure_016_page1.png at position (857, 1491) with confidence 1.00
# Matched measure_023_page1.png at position (310, 2166) with confidence 1.00
# Matched measure_028_page1.png at position (881, 2480) with confidence 1.00
# Matched measure_009_page1.png at position (1374, 810) with confidence 1.00
# Matched measure_031_page1.png at position (332, 2835) with confidence 1.00
# Matched measure_025_page1.png at position (1423, 2141) with confidence 1.00
# Matched measure_004_page1.png at position (1250, 503) with confidence 1.00
# Matched measure_010_page1.png at position (1942, 819) with confidence 1.00
# Matched measure_018_page1.png at position (1957, 1466) with confidence 1.00
# Matched measure_020_page1.png at position (864, 1813) with confidence 1.00
# Matched measure_015_page1.png at position (303, 1500) with confidence 1.00
# Matched measure_001_page1.png at position (254, 512) with confidence 1.00
# Matched measure_013_page1.png at position (1388, 1168) with confidence 1.00
# Matched measure_007_page1.png at position (288, 863) with confidence 1.00
# Matched measure_026_page1.png at position (1982, 2117) with confidence 1.00
# Matched measure_032_page1.png at position (872, 2829) with confidence 1.00
# Matched measure_019_page1.png at position (304, 1831) with confidence 1.00
# Matched measure_021_page1.png at position (1409, 1817) with confidence 1.00
# Matched measure_014_page1.png at position (1955, 1159) with confidence 1.00
# Matched measure_006_page1.png at position (2042, 491) with confidence 1.00
# Matched measure_012_page1.png at position (848, 1132) with confidence 1.00
# Matched measure_027_page1.png at position (323, 2503) with confidence 1.00
# Visualization saved to measures_pngs/They-Cant-Take-That-Away-From-Me/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_002_page1.png to measure_002_page1.png
# Copied measure_003_page1.png to measure_003_page1.png
# Copied measure_004_page1.png to measure_004_page1.png
# Copied measure_005_page1.png to measure_005_page1.png
# Copied measure_006_page1.png to measure_006_page1.png
# Copied measure_007_page1.png to measure_007_page1.png
# Copied measure_008_page1.png to measure_008_page1.png
# Copied measure_009_page1.png to measure_009_page1.png
# Copied measure_010_page1.png to measure_010_page1.png
# Copied measure_011_page1.png to measure_011_page1.png
# Copied measure_012_page1.png to measure_012_page1.png
# Copied measure_013_page1.png to measure_013_page1.png
# Copied measure_014_page1.png to measure_014_page1.png
# Copied measure_015_page1.png to measure_015_page1.png
# Copied measure_016_page1.png to measure_016_page1.png
# Copied measure_017_page1.png to measure_017_page1.png
# Copied measure_018_page1.png to measure_018_page1.png
# Copied measure_019_page1.png to measure_019_page1.png
# Copied measure_020_page1.png to measure_020_page1.png
# Copied measure_021_page1.png to measure_021_page1.png
# Copied measure_022_page1.png to measure_022_page1.png
# Copied measure_023_page1.png to measure_023_page1.png
# Copied measure_024_page1.png to measure_024_page1.png
# Copied measure_025_page1.png to measure_025_page1.png
# Copied measure_026_page1.png to measure_026_page1.png
# Copied measure_027_page1.png to measure_027_page1.png
# Copied measure_028_page1.png to measure_028_page1.png
# Copied measure_029_page1.png to measure_029_page1.png
# Copied measure_030_page1.png to measure_030_page1.png
# Copied measure_031_page1.png to measure_031_page1.png
# Copied measure_032_page1.png to measure_032_page1.png
# Finished processing song folder: They-Cant-Take-That-Away-From-Me
# Total measures: 32, Copied: 32
# Ordered measures saved to: measures_pngs/They-Cant-Take-That-Away-From-Me/final_measures
#
# Processing song folder: Four
# Created output directory: measures_pngs/Four/final_measures
# Processing page 1 with sheet music: Four_1.png
# Matched measure_017_page1.png at position (1802, 1811) with confidence 1.00
# Matched measure_003_page1.png at position (644, 233) with confidence 1.00
# Matched measure_022_page1.png at position (1808, 2325) with confidence 1.00
# Matched measure_008_page1.png at position (1260, 822) with confidence 1.00
# Matched measure_024_page1.png at position (2099, 2330) with confidence 1.00
# Matched measure_011_page1.png at position (706, 1309) with confidence 1.00
# Matched measure_005_page1.png at position (1813, 361) with confidence 1.00
# Matched measure_016_page1.png at position (1244, 1823) with confidence 1.00
# Matched measure_009_page1.png at position (1807, 856) with confidence 1.00
# Matched measure_004_page1.png at position (1270, 347) with confidence 1.00
# Matched measure_010_page1.png at position (159, 1304) with confidence 1.00
# Matched measure_018_page1.png at position (149, 2285) with confidence 1.00
# Matched measure_020_page1.png at position (654, 2246) with confidence 1.00
# Matched measure_015_page1.png at position (680, 1720) with confidence 1.00
# Matched measure_001_page1.png at position (390, 255) with confidence 0.95 (scale: 1.98)
# Matched measure_013_page1.png at position (1799, 1324) with confidence 1.00
# Matched measure_007_page1.png at position (710, 818) with confidence 1.00
# Matched measure_021_page1.png at position (1248, 2274) with confidence 1.00
# Matched measure_014_page1.png at position (153, 1788) with confidence 1.00
# Matched measure_006_page1.png at position (168, 817) with confidence 1.00
# Matched measure_012_page1.png at position (1250, 1328) with confidence 1.00
# Visualization saved to measures_pngs/Four/new_visualizations/ordering_page1.png
# Copied measure_001_page1.png to measure_001_page1.png
# Copied measure_003_page1.png to measure_002_page1.png
# Copied measure_004_page1.png to measure_003_page1.png
# Copied measure_005_page1.png to measure_004_page1.png
# Copied measure_006_page1.png to measure_005_page1.png
# Copied measure_007_page1.png to measure_006_page1.png
# Copied measure_008_page1.png to measure_007_page1.png
# Copied measure_009_page1.png to measure_008_page1.png
# Copied measure_010_page1.png to measure_009_page1.png
# Copied measure_011_page1.png to measure_010_page1.png
# Copied measure_012_page1.png to measure_011_page1.png
# Copied measure_013_page1.png to measure_012_page1.png
# Copied measure_014_page1.png to measure_013_page1.png
# Copied measure_015_page1.png to measure_014_page1.png
# Copied measure_016_page1.png to measure_015_page1.png
# Copied measure_017_page1.png to measure_016_page1.png
# Copied measure_018_page1.png to measure_017_page1.png
# Copied measure_020_page1.png to measure_018_page1.png
# Copied measure_021_page1.png to measure_019_page1.png
# Copied measure_022_page1.png to measure_020_page1.png
# Copied measure_024_page1.png to measure_021_page1.png
# Finished processing song folder: Four
# Total measures: 21, Copied: 21
# Ordered measures saved to: measures_pngs/Four/final_measures
#
# Batch processing complete. Successfully processed 220 out of 220 song folders.

# %%
import os
import re

base_folder = 'measures_pngs'
pattern = re.compile(r"measure_(\d+)_page1\.png")

for song_folder in os.listdir(base_folder):
    final_measures_path = os.path.join(base_folder, song_folder, 'final_measures')
    
    if not os.path.isdir(final_measures_path):
        continue

    files = [f for f in os.listdir(final_measures_path) if pattern.match(f)]
    files.sort(key=lambda f: int(pattern.match(f).group(1)))

    new_names = {}
    for idx, filename in enumerate(files):
        new_number = idx + 1
        new_filename = f"measure_{new_number:03d}_page1.png"
        new_names[filename] = new_filename

    for old_name, new_name in new_names.items():
        temp_name = f"tmp_{new_name}"
        os.rename(os.path.join(final_measures_path, old_name), os.path.join(final_measures_path, temp_name))

    for old_name, new_name in new_names.items():
        temp_name = f"tmp_{new_name}"
        os.rename(os.path.join(final_measures_path, temp_name), os.path.join(final_measures_path, new_name))

    print(f"Processed: {final_measures_path}")
# Out:
# Processed: measures_pngs/How-Insensitive/final_measures
# Processed: measures_pngs/Prelude-to-a-Kiss/final_measures
# Processed: measures_pngs/Do-You-Know-What-It-Means-To-Means-New-Orleans/final_measures
# Processed: measures_pngs/I-Mean-You/final_measures
# Processed: measures_pngs/Early-Autumn/final_measures
# Processed: measures_pngs/I-Get-a-Kick-Out-of-You/final_measures
# Processed: measures_pngs/Minor-Mood/final_measures
# Processed: measures_pngs/When-I-fall-in-love/final_measures
# Processed: measures_pngs/Careless-Love/final_measures
# Processed: measures_pngs/Cherokee/final_measures
# Processed: measures_pngs/Anthropology/final_measures
# Processed: measures_pngs/Lady-Bird/final_measures
# Processed: measures_pngs/Take-The-A-Train/final_measures
# Processed: measures_pngs/Whisper-Not/final_measures
# Processed: measures_pngs/All-Of-You/final_measures
# Processed: measures_pngs/Moonglow/final_measures
# Processed: measures_pngs/Satin-Doll/final_measures
# Processed: measures_pngs/Meditation/final_measures
# Processed: measures_pngs/Once-I-Loved-O-Amor-Em-Paz/final_measures
# Processed: measures_pngs/Whats-New/final_measures
# Processed: measures_pngs/You-Dont-Know-What-Love-Is/final_measures
# Processed: measures_pngs/You-Are-The-Sunshine-of-My-Life/final_measures
# Processed: measures_pngs/Crazeology/final_measures
# Processed: measures_pngs/Who-Can-I-Turn-To/final_measures
# Processed: measures_pngs/Yardbird-Suite/final_measures
# Processed: measures_pngs/Till-There-Was-You/final_measures
# Processed: measures_pngs/Nature-Boy/final_measures
# Processed: measures_pngs/Love-For-Sale/final_measures
# Processed: measures_pngs/Lover/final_measures
# Processed: measures_pngs/Out-Of-Nowhere/final_measures
# Processed: measures_pngs/Just-in-Time/final_measures
# Processed: measures_pngs/On-a-Clear-Day-You-Can-See-Forever/final_measures
# Processed: measures_pngs/Youd-Be-So-Nice-to-Come-Home-To/final_measures
# Processed: measures_pngs/Alice-In-Wonderland/final_measures
# Processed: measures_pngs/Darn-That-Dream/final_measures
# Processed: measures_pngs/My-Ship/final_measures
# Processed: measures_pngs/It-dont-mean-a-thing/final_measures
# Processed: measures_pngs/Groovin-High/final_measures
# Processed: measures_pngs/Pennies-from-Heaven/final_measures
# Processed: measures_pngs/But-Not-For-Me/final_measures
# Processed: measures_pngs/Embraceable-You/final_measures
# Processed: measures_pngs/52nd-Street-Theme/final_measures
# Processed: measures_pngs/Bewitched/final_measures
# Processed: measures_pngs/Petit-Fleur/final_measures
# Processed: measures_pngs/Just-The-Way-You-Are/final_measures
# Processed: measures_pngs/Softly-as-in-a-Morning-Sunrise/final_measures
# Processed: measures_pngs/Perdido/final_measures
# Processed: measures_pngs/Nefertiti/final_measures
# Processed: measures_pngs/Bohemia-After-Dark/final_measures
# Processed: measures_pngs/Countdown/final_measures
# Processed: measures_pngs/Chameleon/final_measures
# Processed: measures_pngs/Pee-Wee/final_measures
# Processed: measures_pngs/How-High-The-Moon/final_measures
# Processed: measures_pngs/Old-Devil-Moon/final_measures
# Processed: measures_pngs/Autumn-Leaves/final_measures
# Processed: measures_pngs/All-The-Things-You-Are-20220715-214738/final_measures
# Processed: measures_pngs/Footprints/final_measures
# Processed: measures_pngs/These-Foolish-Things/final_measures
# Processed: measures_pngs/Minority/final_measures
# Processed: measures_pngs/I-Thought-About-You/final_measures
# Processed: measures_pngs/Mood-Indigo/final_measures
# Processed: measures_pngs/Chelsea-Bridge/final_measures
# Processed: measures_pngs/Things-Aint-What-They-Used-To-Be/final_measures
# Processed: measures_pngs/Yesterdays/final_measures
# Processed: measures_pngs/Caravan-20220715-215146/final_measures
# Processed: measures_pngs/Five-Brothers/final_measures
# Processed: measures_pngs/Alone-Together/final_measures
# Processed: measures_pngs/And-On-The-Third-Day/final_measures
# Processed: measures_pngs/Easy-Living/final_measures
# Processed: measures_pngs/I-Love-You/final_measures
# Processed: measures_pngs/Airmail-Special/final_measures
# Processed: measures_pngs/Lullaby-of-birdland/final_measures
# Processed: measures_pngs/Its-Only-A-Paper-Moon/final_measures
# Processed: measures_pngs/Billies-bounce/final_measures
# Processed: measures_pngs/Have-You-Met-Miss-Jones/final_measures
# Processed: measures_pngs/Good-Bait/final_measures
# Processed: measures_pngs/Indiana/final_measures
# Processed: measures_pngs/Limehouse-Blues/final_measures
# Processed: measures_pngs/It-had-to-be-you/final_measures
# Processed: measures_pngs/Nows-the-Time/final_measures
# Processed: measures_pngs/Body-And-Soul-20220717-102403/final_measures
# Processed: measures_pngs/Just-You-Just-Me/final_measures
# Processed: measures_pngs/My-favorite-things/final_measures
# Processed: measures_pngs/Corcovado-1/final_measures
# Processed: measures_pngs/Up-Jumped-Spring/final_measures
# Processed: measures_pngs/Scotch-and-Soda/final_measures
# Processed: measures_pngs/502-Blues/final_measures
# Processed: measures_pngs/Afternoon-In-Paris/final_measures
# Processed: measures_pngs/Bloomdido/final_measures
# Processed: measures_pngs/Robbins-Nest/final_measures
# Processed: measures_pngs/Come-Sunday/final_measures
# Processed: measures_pngs/Peace/final_measures
# Processed: measures_pngs/Half-Nelson/final_measures
# Processed: measures_pngs/Nardis/final_measures
# Processed: measures_pngs/My-Romance/final_measures
# Processed: measures_pngs/Get-Out-of-Town/final_measures
# Processed: measures_pngs/Here-s-That-Rainy-Day/final_measures
# Processed: measures_pngs/All-Gods-Chillun-Got-Rhythm/final_measures
# Processed: measures_pngs/My-Little-Suede-Shoes/final_measures
# Processed: measures_pngs/Stella-by-Starlight/final_measures
# Processed: measures_pngs/Alfies-Theme/final_measures
# Processed: measures_pngs/I-Could-Write-a-Book/final_measures
# Processed: measures_pngs/Well-You-Neednt/final_measures
# Processed: measures_pngs/Birth-of-the-Blues/final_measures
# Processed: measures_pngs/Speak-Low/final_measures
# Processed: measures_pngs/Dont-Blame-Me/final_measures
# Processed: measures_pngs/Stardust/final_measures
# Processed: measures_pngs/If-I-Should-Lose-You/final_measures
# Processed: measures_pngs/Giant-steps/final_measures
# Processed: measures_pngs/Angel-Eyes/final_measures
# Processed: measures_pngs/Airegin-1/final_measures
# Processed: measures_pngs/Deep-Purple/final_measures
# Processed: measures_pngs/Daahoud/final_measures
# Processed: measures_pngs/My-Funny-Valentine/final_measures
# Processed: measures_pngs/Triste/final_measures
# Processed: measures_pngs/Sometime-Ago/final_measures
# Processed: measures_pngs/Dont-Get-Around-Much-Anymore/final_measures
# Processed: measures_pngs/God-Bless-the-Child/final_measures
# Processed: measures_pngs/Freddie-Freeloader/final_measures
# Processed: measures_pngs/Lover-Man/final_measures
# Processed: measures_pngs/I-Cover-the-Waterfront/final_measures
# Processed: measures_pngs/If-I-Were-a-Bell/final_measures
# Processed: measures_pngs/Donna-Lee/final_measures
# Processed: measures_pngs/Imagination/final_measures
# Processed: measures_pngs/Smok-Gets-In-Your-Eyes/final_measures
# Processed: measures_pngs/Elizete/final_measures
# Processed: measures_pngs/Lush-Life/final_measures
# Processed: measures_pngs/Ive-found-a-new-baby/final_measures
# Processed: measures_pngs/Mercy-Mercy-Mercy/final_measures
# Processed: measures_pngs/Bebop/final_measures
# Processed: measures_pngs/September-Song/final_measures
# Processed: measures_pngs/Portrait-of-Jennie/final_measures
# Processed: measures_pngs/Recado-Bossa-Nova-The-Gift/final_measures
# Processed: measures_pngs/Scrapple-from-the-Apple/final_measures
# Processed: measures_pngs/A-Fine-Romance/final_measures
# Processed: measures_pngs/Black-Orheus/final_measures
# Processed: measures_pngs/Laura/final_measures
# Processed: measures_pngs/When-Sunny-Gets-Blue/final_measures
# Processed: measures_pngs/Au-Privave/final_measures
# Processed: measures_pngs/Con-Alma/final_measures
# Processed: measures_pngs/But-Beautiful/final_measures
# Processed: measures_pngs/Blue-Moon/final_measures
# Processed: measures_pngs/In-a-Sentimental-Mood/final_measures
# Processed: measures_pngs/All-Of-Me/final_measures
# Processed: measures_pngs/Take-Five/final_measures
# Processed: measures_pngs/Dolphin-Dance/final_measures
# Processed: measures_pngs/Forest-Flower/final_measures
# Processed: measures_pngs/Epistrophy/final_measures
# Processed: measures_pngs/Do-Nothing-till-You-Hear-from-Me/final_measures
# Processed: measures_pngs/Joy-Spring/final_measures
# Processed: measures_pngs/Sister-Sadie/final_measures
# Processed: measures_pngs/Misty/final_measures
# Processed: measures_pngs/What-Is-This-Thing-Called-Love/final_measures
# Processed: measures_pngs/Jumpin-With-Symphony-Sid/final_measures
# Processed: measures_pngs/What-Are-You-Doing-the-Rest-of-Your-Life/final_measures
# Processed: measures_pngs/April-In-Paris/final_measures
# Processed: measures_pngs/Basin-Street-Blues/final_measures
# Processed: measures_pngs/Fee-Fi-Fo-Fum/final_measures
# Processed: measures_pngs/Virgo/final_measures
# Processed: measures_pngs/C-Jam-Blues/final_measures
# Processed: measures_pngs/Willow-Weep-for-Me/final_measures
# Processed: measures_pngs/Blue-Monk/final_measures
# Processed: measures_pngs/E-S-P/final_measures
# Processed: measures_pngs/Someday-My-Prince-Will-Come/final_measures
# Processed: measures_pngs/Dindi/final_measures
# Processed: measures_pngs/Desafinado/final_measures
# Processed: measures_pngs/Summertime/final_measures
# Processed: measures_pngs/Tenderly/final_measures
# Processed: measures_pngs/I-Remember-Clifford/final_measures
# Processed: measures_pngs/Soul-Eyes/final_measures
# Processed: measures_pngs/Sweet-Georgia-Brown/final_measures
# Processed: measures_pngs/Wave/final_measures
# Processed: measures_pngs/Fly-Me-To-The-Moon-20220717-111202/final_measures
# Processed: measures_pngs/Night-and-day/final_measures
# Processed: measures_pngs/Cool-Blues/final_measures
# Processed: measures_pngs/Im-a-Fool-to-Want-You/final_measures
# Processed: measures_pngs/All-Blues/final_measures
# Processed: measures_pngs/Autumn-in-NY/final_measures
# Processed: measures_pngs/Windows/final_measures
# Processed: measures_pngs/Impressions/final_measures
# Processed: measures_pngs/Oleo/final_measures
# Processed: measures_pngs/Beautiful-Love/final_measures
# Processed: measures_pngs/Hackensack/final_measures
# Processed: measures_pngs/Im-Getting-Sentimental-Over-You/final_measures
# Processed: measures_pngs/For-Heavens-Sake/final_measures
# Processed: measures_pngs/Ana-Maria/final_measures
# Processed: measures_pngs/If-You-Never-Come-to-Me-Inutil-Paisagem/final_measures
# Processed: measures_pngs/My-One-and-Only-Love/final_measures
# Processed: measures_pngs/Naima/final_measures
# Processed: measures_pngs/There-will-never-be-another-you/final_measures
# Processed: measures_pngs/My-Foolish-Heart/final_measures
# Processed: measures_pngs/Blue-Room/final_measures
# Processed: measures_pngs/Four-Brothers/final_measures
# Processed: measures_pngs/Invitation/final_measures
# Processed: measures_pngs/Taking-A-Chance-On-Love/final_measures
# Processed: measures_pngs/Round-Midnight/final_measures
# Processed: measures_pngs/A-Foggy-Day/final_measures
# Processed: measures_pngs/Barbados/final_measures
# Processed: measures_pngs/In-A-Mellow-Tone/final_measures
# Processed: measures_pngs/Summer-Samba/final_measures
# Processed: measures_pngs/As-Time-Goes-By/final_measures
# Processed: measures_pngs/Avalon/final_measures
# Processed: measures_pngs/One-Note-Samba/final_measures
# Processed: measures_pngs/Bye-Bye-Blackbird/final_measures
# Processed: measures_pngs/Afro-Blue/final_measures
# Processed: measures_pngs/Interplay/final_measures
# Processed: measures_pngs/Days-Of-Wine-And-Roses-20220715-215340/final_measures
# Processed: measures_pngs/I-Cant-Get-Started/final_measures
# Processed: measures_pngs/Ceora/final_measures
# Processed: measures_pngs/Bluesette-1/final_measures
# Processed: measures_pngs/Nicas-Dream/final_measures
# Processed: measures_pngs/You-Took-Advantage-Of-Me/final_measures
# Processed: measures_pngs/All-My-Tomorrows/final_measures
# Processed: measures_pngs/Molten-Glass/final_measures
# Processed: measures_pngs/Come-Rain-or-Come-Shine/final_measures
# Processed: measures_pngs/There-Is-No-Greater-Love/final_measures
# Processed: measures_pngs/Fools-Rush-In/final_measures
# Processed: measures_pngs/They-Cant-Take-That-Away-From-Me/final_measures
# Processed: measures_pngs/Four/final_measures
